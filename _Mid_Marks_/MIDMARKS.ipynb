# %% [markdown]
# # 2211CS010331

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df=pd.read_csv("midmarks.csv")

# %%
df
# Out:
#      S.NO SECTION  DV M-II  PP BEEE  FL FIMS
# 0     1.0   ALPHA  12    0  17    9  19   15
# 1     2.0   ALPHA  19   12  16   16  18    3
# 2     3.0   ALPHA  18   14  18   18  18   16
# 3     4.0   ALPHA  15    9  19   17  19   15
# 4     5.0   ALPHA  18   17  19   19  20   18
# ..    ...     ...  ..  ...  ..  ...  ..  ...
# 713   NaN    ZETA  19    8   8   19  17   18
# 714   NaN    ZETA  12    1   7   10  20    8
# 715   NaN    ZETA  17    6  14   14  17   18
# 716   NaN    ZETA  12    1   6    7  15   12
# 717   NaN    ZETA  19   14  17   16  20   19
#
# [718 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 718 entries, 0 to 717
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   S.NO     601 non-null    float64
#  1   SECTION  691 non-null    object
#  2   DV       716 non-null    object
#  3   M-II     716 non-null    object
#  4   PP       716 non-null    object
#  5   BEEE     716 non-null    object
#  6   FL       715 non-null    object
#  7   FIMS     716 non-null    object
# dtypes: float64(1), object(7)
# memory usage: 45.0+ KB

# %%
df.isnull().sum()
# Out:
# S.NO       117
# SECTION     27
# DV           2
# M-II         2
# PP           2
# BEEE         2
# FL           3
# FIMS         2
# dtype: int64

# %%
df['SECTION'] = df['SECTION'].fillna('SIGMA') 
df['SECTION'] = df['SECTION'].replace('', 'SIGMA')
df
# Out:
#      S.NO SECTION  DV M-II  PP BEEE  FL FIMS
# 0     1.0   ALPHA  12    0  17    9  19   15
# 1     2.0   ALPHA  19   12  16   16  18    3
# 2     3.0   ALPHA  18   14  18   18  18   16
# 3     4.0   ALPHA  15    9  19   17  19   15
# 4     5.0   ALPHA  18   17  19   19  20   18
# ..    ...     ...  ..  ...  ..  ...  ..  ...
# 713   NaN    ZETA  19    8   8   19  17   18
# 714   NaN    ZETA  12    1   7   10  20    8
# 715   NaN    ZETA  17    6  14   14  17   18
# 716   NaN    ZETA  12    1   6    7  15   12
# 717   NaN    ZETA  19   14  17   16  20   19
#
# [718 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 718 entries, 0 to 717
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   S.NO     601 non-null    float64
#  1   SECTION  718 non-null    object
#  2   DV       716 non-null    object
#  3   M-II     716 non-null    object
#  4   PP       716 non-null    object
#  5   BEEE     716 non-null    object
#  6   FL       715 non-null    object
#  7   FIMS     716 non-null    object
# dtypes: float64(1), object(7)
# memory usage: 45.0+ KB

# %%
df['S.NO'] = range(1, len(df) + 1)
df
# Out:
#      S.NO SECTION  DV M-II  PP BEEE  FL FIMS
# 0       1   ALPHA  12    0  17    9  19   15
# 1       2   ALPHA  19   12  16   16  18    3
# 2       3   ALPHA  18   14  18   18  18   16
# 3       4   ALPHA  15    9  19   17  19   15
# 4       5   ALPHA  18   17  19   19  20   18
# ..    ...     ...  ..  ...  ..  ...  ..  ...
# 713   714    ZETA  19    8   8   19  17   18
# 714   715    ZETA  12    1   7   10  20    8
# 715   716    ZETA  17    6  14   14  17   18
# 716   717    ZETA  12    1   6    7  15   12
# 717   718    ZETA  19   14  17   16  20   19
#
# [718 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 718 entries, 0 to 717
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   S.NO     718 non-null    int64
#  1   SECTION  718 non-null    object
#  2   DV       716 non-null    object
#  3   M-II     716 non-null    object
#  4   PP       716 non-null    object
#  5   BEEE     716 non-null    object
#  6   FL       715 non-null    object
#  7   FIMS     716 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 45.0+ KB

# %%
df['FL'] = df['FL'].fillna(0) 
df=df.dropna()

# %%
df
# Out:
#      S.NO SECTION  DV M-II  PP BEEE  FL FIMS
# 0       1   ALPHA  12    0  17    9  19   15
# 1       2   ALPHA  19   12  16   16  18    3
# 2       3   ALPHA  18   14  18   18  18   16
# 3       4   ALPHA  15    9  19   17  19   15
# 4       5   ALPHA  18   17  19   19  20   18
# ..    ...     ...  ..  ...  ..  ...  ..  ...
# 713   714    ZETA  19    8   8   19  17   18
# 714   715    ZETA  12    1   7   10  20    8
# 715   716    ZETA  17    6  14   14  17   18
# 716   717    ZETA  12    1   6    7  15   12
# 717   718    ZETA  19   14  17   16  20   19
#
# [716 rows x 8 columns]

# %%
df.columns
# Out:
# Index(['S.NO', 'SECTION', 'DV', 'M-II', 'PP', 'BEEE', 'FL', 'FIMS'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 716 entries, 0 to 717
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   S.NO     716 non-null    int64
#  1   SECTION  716 non-null    object
#  2   DV       716 non-null    object
#  3   M-II     716 non-null    object
#  4   PP       716 non-null    object
#  5   BEEE     716 non-null    object
#  6   FL       716 non-null    object
#  7   FIMS     716 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 50.3+ KB

# %%
df.isnull().sum()
# Out:
# S.NO       0
# SECTION    0
# DV         0
# M-II       0
# PP         0
# BEEE       0
# FL         0
# FIMS       0
# dtype: int64

# %%
df.rename(columns ={"M-II":"M2"},inplace=True)
df
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_21436\1333268720.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns ={"M-II":"M2"},inplace=True)
#      S.NO SECTION  DV  M2  PP BEEE  FL FIMS
# 0       1   ALPHA  12   0  17    9  19   15
# 1       2   ALPHA  19  12  16   16  18    3
# 2       3   ALPHA  18  14  18   18  18   16
# 3       4   ALPHA  15   9  19   17  19   15
# 4       5   ALPHA  18  17  19   19  20   18
# ..    ...     ...  ..  ..  ..  ...  ..  ...
# 713   714    ZETA  19   8   8   19  17   18
# 714   715    ZETA  12   1   7   10  20    8
# 715   716    ZETA  17   6  14   14  17   18
# 716   717    ZETA  12   1   6    7  15   12
# 717   718    ZETA  19  14  17   16  20   19
#
# [716 rows x 8 columns]

# %%
df.SECTION.fillna("SIGMA")
# Out:
# 0      ALPHA
# 1      ALPHA
# 2      ALPHA
# 3      ALPHA
# 4      ALPHA
#        ...
# 713     ZETA
# 714     ZETA
# 715     ZETA
# 716     ZETA
# 717     ZETA
# Name: SECTION, Length: 716, dtype: object

# %%
columns_to_convert = ['DV', 'M2', 'PP', 'BEEE', 'FL', 'FIMS']
for column in columns_to_convert:
    df[column] = pd.to_numeric(df[column], errors='coerce').fillna(0)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_21436\1326894529.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = pd.to_numeric(df[column], errors='coerce').fillna(0)

# %%
df[['DV', 'M2', 'PP', 'BEEE', 'FL', 'FIMS']] = df[['DV', 'M2', 'PP', 'BEEE', 'FL', 'FIMS']].astype('float64')
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_21436\3850921465.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['DV', 'M2', 'PP', 'BEEE', 'FL', 'FIMS']] = df[['DV', 'M2', 'PP', 'BEEE', 'FL', 'FIMS']].astype('float64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 716 entries, 0 to 717
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   S.NO     716 non-null    int64
#  1   SECTION  716 non-null    object
#  2   DV       716 non-null    float64
#  3   M2       716 non-null    float64
#  4   PP       716 non-null    float64
#  5   BEEE     716 non-null    float64
#  6   FL       716 non-null    float64
#  7   FIMS     716 non-null    float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 50.3+ KB

# %%
df['BC']=(df[['DV','M2','PP','BEEE','FL','FIMS']]<10).sum(axis=1)
df
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_21436\3783423686.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['BC']=(df[['DV','M2','PP','BEEE','FL','FIMS']]<10).sum(axis=1)
#      S.NO SECTION    DV    M2    PP  BEEE    FL  FIMS  BC
# 0       1   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0   2
# 1       2   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0   1
# 2       3   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0   0
# 3       4   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0   1
# 4       5   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0   0
# ..    ...     ...   ...   ...   ...   ...   ...   ...  ..
# 713   714    ZETA  19.0   8.0   8.0  19.0  17.0  18.0   2
# 714   715    ZETA  12.0   1.0   7.0  10.0  20.0   8.0   3
# ...

# %%
df['IS_BACKLOG'] = df['DV'] < 10
backlog_counts = df.groupby('SECTION')['IS_BACKLOG'].sum()
backlog_counts
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_21436\2815034705.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['IS_BACKLOG'] = df['DV'] < 10
# SECTION
# ALPHA      17
# BETA       17
# DELTA      14
# EPSILON     4
# GAMMA      11
# OMEGA      10
# SIGMA       6
# ZETA        8
# Name: IS_BACKLOG, dtype: int64

# %%
subject_cols = ['DV', 'M2', 'PP', 'BEEE', 'FL', 'FIMS']
backlog_counts = df[subject_cols].lt(10).groupby(df['SECTION']).sum()
print(backlog_counts)
# Out:
#          DV  M2  PP  BEEE  FL  FIMS
# SECTION
# ALPHA    17  18  12     8   1    22
# BETA     17  25   8    41   1    11
# DELTA    14  45  28    46   1     4
# EPSILON   4  64  49    17   8    22
# GAMMA    11  46  36    17   2    23
# OMEGA    10  58  16    21  12     7
# SIGMA     6  28  14    23   2     9
# ZETA      8  63  50    18  15    20

# %%
subject_cols = ['DV', 'M2', 'PP', 'BEEE', 'FL', 'FIMS']
df['TOTAL_BACKLOGS'] = (df[subject_cols] < 10).sum(axis=1)
backlog_counts = df.groupby('SECTION')['TOTAL_BACKLOGS'].sum()
print(backlog_counts)
# Out:
# SECTION
# ALPHA       78
# BETA       103
# DELTA      138
# EPSILON    164
# GAMMA      135
# OMEGA      124
# SIGMA       82
# ZETA       174
# Name: TOTAL_BACKLOGS, dtype: int64
# C:\Users\DELL\AppData\Local\Temp\ipykernel_21436\2820472478.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['TOTAL_BACKLOGS'] = (df[subject_cols] < 10).sum(axis=1)

# %%
subject_cols = ['DV', 'M2', 'PP', 'BEEE', 'FL', 'FIMS']

backlog_counts = df[subject_cols].lt(10).groupby(df['SECTION']).sum()

df['Total Backlogs'] = df[subject_cols].lt(10).sum(axis=1)

total_backlogs_per_section = df.groupby('SECTION')['Total Backlogs'].sum()


combined_backlog_data = pd.concat([backlog_counts, total_backlogs_per_section], axis=1)

print(combined_backlog_data)
# Out:
#          DV  M2  PP  BEEE  FL  FIMS  Total Backlogs
# SECTION
# ALPHA    17  18  12     8   1    22              78
# BETA     17  25   8    41   1    11             103
# DELTA    14  45  28    46   1     4             138
# EPSILON   4  64  49    17   8    22             164
# GAMMA    11  46  36    17   2    23             135
# OMEGA    10  58  16    21  12     7             124
# SIGMA     6  28  14    23   2     9              82
# ZETA      8  63  50    18  15    20             174
# C:\Users\DELL\AppData\Local\Temp\ipykernel_21436\466466176.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Total Backlogs'] = df[subject_cols].lt(10).sum(axis=1)

# %%
df_cleaned = df.dropna(how = 'all')
print(df_cleaned)
# Out:
#      S.NO SECTION    DV    M2    PP  BEEE    FL  FIMS  BC  IS_BACKLOG  \
# 0       1   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0   2       False
# 1       2   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0   1       False
# 2       3   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0   0       False
# 3       4   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0   1       False
# 4       5   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0   0       False
# ..    ...     ...   ...   ...   ...   ...   ...   ...  ..         ...
# 713   714    ZETA  19.0   8.0   8.0  19.0  17.0  18.0   2       False
# 714   715    ZETA  12.0   1.0   7.0  10.0  20.0   8.0   3       False
# 715   716    ZETA  17.0   6.0  14.0  14.0  17.0  18.0   1       False
# 716   717    ZETA  12.0   1.0   6.0   7.0  15.0  12.0   3       False
# 717   718    ZETA  19.0  14.0  17.0  16.0  20.0  19.0   0       False
#
#      TOTAL_BACKLOGS  Total Backlogs
# 0                 2               2
# 1                 1               1
# ...

# %%
cols = ['DV', 'M2', 'PP', 'BEEE', 'FL', 'FIMS']
df[cols] = df[cols].apply(pd.to_numeric, errors='coerce')
df[cols] = df[cols].fillna(0)
df['Total'] = df[cols].sum(axis=1)
print(df)
# Out:
#      S.NO SECTION    DV    M2    PP  BEEE    FL  FIMS  BC  IS_BACKLOG  \
# 0       1   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0   2       False
# 1       2   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0   1       False
# 2       3   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0   0       False
# 3       4   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0   1       False
# 4       5   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0   0       False
# ..    ...     ...   ...   ...   ...   ...   ...   ...  ..         ...
# 713   714    ZETA  19.0   8.0   8.0  19.0  17.0  18.0   2       False
# 714   715    ZETA  12.0   1.0   7.0  10.0  20.0   8.0   3       False
# 715   716    ZETA  17.0   6.0  14.0  14.0  17.0  18.0   1       False
# 716   717    ZETA  12.0   1.0   6.0   7.0  15.0  12.0   3       False
# 717   718    ZETA  19.0  14.0  17.0  16.0  20.0  19.0   0       False
#
#      TOTAL_BACKLOGS  Total Backlogs  Total
# 0                 2               2   72.0
# ...

# %%
def assign_grade(total):
    if total >= 90:
        return 'A'
    elif total >= 75:
        return 'B'
    elif total >= 60:
        return 'C'
    elif total >= 50:
        return 'D'
    else:
        return 'F'
df['Grade'] = df['Total'].apply(assign_grade)
print(df)
# Out:
#      S.NO SECTION    DV    M2    PP  BEEE    FL  FIMS  BC  IS_BACKLOG  \
# 0       1   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0   2       False
# 1       2   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0   1       False
# 2       3   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0   0       False
# 3       4   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0   1       False
# 4       5   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0   0       False
# ..    ...     ...   ...   ...   ...   ...   ...   ...  ..         ...
# 713   714    ZETA  19.0   8.0   8.0  19.0  17.0  18.0   2       False
# 714   715    ZETA  12.0   1.0   7.0  10.0  20.0   8.0   3       False
# 715   716    ZETA  17.0   6.0  14.0  14.0  17.0  18.0   1       False
# 716   717    ZETA  12.0   1.0   6.0   7.0  15.0  12.0   3       False
# 717   718    ZETA  19.0  14.0  17.0  16.0  20.0  19.0   0       False
#
#      TOTAL_BACKLOGS  Total Backlogs  Total Grade
# 0                 2               2   72.0     C
# ...

# %%
import numpy as np
df['Grade']
# Out:
# 0      C
# 1      B
# 2      A
# 3      A
# 4      A
#       ..
# 713    B
# 714    D
# 715    B
# 716    D
# 717    A
# Name: Grade, Length: 716, dtype: object

# %%
import numpy as np
max_total_marks = 120  
df['Percentage'] = (df['Total'] / max_total_marks) * 100
df['Percentage'] = np.ceil(df['Percentage'])
print(df)
# Out:
#      S.NO SECTION    DV    M2    PP  BEEE    FL  FIMS  BC  IS_BACKLOG  \
# 0       1   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0   2       False
# 1       2   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0   1       False
# 2       3   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0   0       False
# 3       4   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0   1       False
# 4       5   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0   0       False
# ..    ...     ...   ...   ...   ...   ...   ...   ...  ..         ...
# 713   714    ZETA  19.0   8.0   8.0  19.0  17.0  18.0   2       False
# 714   715    ZETA  12.0   1.0   7.0  10.0  20.0   8.0   3       False
# 715   716    ZETA  17.0   6.0  14.0  14.0  17.0  18.0   1       False
# 716   717    ZETA  12.0   1.0   6.0   7.0  15.0  12.0   3       False
# 717   718    ZETA  19.0  14.0  17.0  16.0  20.0  19.0   0       False
#
#      TOTAL_BACKLOGS  Total Backlogs  Total Grade  Percentage
# 0                 2               2   72.0     C        60.0
# ...

# %%
plt.hist(df['FL'], color='teal', edgecolor='black', bins=6)
plt.title('Histogram of FL Marks')
plt.xlabel('Marks in FL')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### The majority of students scored within the mid-range of marks, suggesting a balanced level of difficulty in FL.

# %%
plt.hist(df['M2'], color='darkblue', edgecolor='black', bins=7)
plt.title('Histogram of M2 Marks')
plt.xlabel('Marks in M2')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### The distribution shows a slight skew towards higher marks, suggesting that M-II was well-understood by students.

# %%
plt.scatter(df['FL'], df['DV'], color='darkorange', edgecolor='black', s=30)
plt.title('Scatter Plot: FL vs DV')
plt.xlabel('Marks in FL')
plt.ylabel('Marks in DV')
plt.show()

# %% [markdown]
# ### A positive correlation is observed between FL and DV scores, meaning students who performed well in FL tended to perform well in DV as well.

# %%
plt.scatter(df['PP'], df['M2'], color='cyan', edgecolor='black', s=25)
plt.title('Scatter Plot: PP vs M2')
plt.xlabel('Marks in PP')
plt.ylabel('Marks in M2')
plt.show()

# %% [markdown]
# ### A slight negative trend is visible, suggesting that students who scored higher in PP often scored lower in M-II.

# %%
df.boxplot(column=['FL'], grid=False, color=dict(boxes='darkred', whiskers='black'))
plt.title('Boxplot of FL Marks')
plt.ylabel('Marks in FL')
plt.show()

# %% [markdown]
# ### FL marks show a few outliers, with most scores concentrated in the mid-to-high range.

# %%
df.boxplot(column=['PP'], grid=False, color=dict(boxes='green', whiskers='black'))
plt.title('Boxplot of PP Marks')
plt.ylabel('Marks in PP')
plt.show()

# %% [markdown]
# ### PP marks show high variability, with a broad range and a few outliers on the lower side.

# %% [markdown]
# ### Average Marks per Subject

# %%
plt.figure(figsize=(10, 6))
subject_columns = ['DV', 'M2', 'PP', 'BEEE', 'FL', 'FIMS']
subject_averages = df[subject_columns].mean()
subject_averages.plot(kind='bar', color='magenta')
plt.title('Average Marks per Subject')
plt.xlabel('Subjects')
plt.ylabel('Average Marks')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()

# %% [markdown]
# ### The bar plot highlights average scores in each subject, revealing that "FL" has the highest average, while "M-II" has the lowest.

# %% [markdown]
# ### Total Marks Distribution¶

# %%
df['TOTAL'] = df[['DV', 'M2', 'PP', 'BEEE', 'FL', 'FIMS']].sum(axis=1)
plt.figure(figsize=[8, 6])
plt.hist(df['TOTAL'], color='blue', bins=10, edgecolor='black')
plt.title("Distribution of Total Marks")
plt.xlabel("Total Marks")
plt.ylabel("Number of Students")
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_21436\456020260.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['TOTAL'] = df[['DV', 'M2', 'PP', 'BEEE', 'FL', 'FIMS']].sum(axis=1)

# %% [markdown]
# ### Most students scored total marks within the mid-to-high range, with fewer students scoring low.

# %% [markdown]
# ### Percentage Distribution

# %%
max_marks_per_subject = 100
num_subjects = len(subject_columns)
max_total_marks = max_marks_per_subject * num_subjects
df['Percentage'] = (df['TOTAL'] / max_total_marks) * 100
plt.figure(figsize=(8, 5))
plt.hist(df['Percentage'], bins=10, color='teal', edgecolor='black')
plt.title('Distribution of Percentages')
plt.xlabel('Percentage')
plt.ylabel('Frequency')
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_21436\54024559.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Percentage'] = (df['TOTAL'] / max_total_marks) * 100

# %% [markdown]
# ### The majority of students achieved percentages within the 60-80% range, indicating decent overall performance.¶

# %% [markdown]
# ### Subject Wise Performance

# %%
plt.figure(figsize=[8, 6])
subject_averages.plot(kind='pie', autopct='%1.1f%%', colors=['green', 'orange', 'blue', 'red', 'purple', 'yellow'])
plt.title("Subject-wise Average Scores")
plt.ylabel('')  
plt.show()

# %% [markdown]
# ### The pie chart shows the proportional contribution of average marks in each subject, with "FL" having the largest share.

# %%
average_total_by_section = df.groupby('SECTION')['TOTAL'].mean()
plt.figure(figsize=[8, 6])
average_total_by_section.plot(kind='pie', autopct='%1.1f%%', colors=['cyan', 'magenta', 'lime', 'gold', 'violet', 'darkorange'])
plt.title("Average Total Marks by Section")
plt.ylabel('')  
plt.show()

# %% [markdown]
# ### Section-wise performance is evenly distributed, with minor variations in average total marks.

# %% [markdown]
# ### Marks in PP vs BEEE

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
sns.lineplot(x="SECTION", y="TOTAL", data=df) 
sns.set_style("dark")
plt.show()

# %%
plt.figure(figsize=(4, 6))
sns.lineplot(x="DV", y="M2", data=df) 
plt.title("Line Plot of DV vs M2")
plt.show()

# %%
sns.set_context("paper", font_scale=1.02)
sns.boxplot(x="SECTION", y="DV", data=df)
plt.title("Boxplot of DV Across SECTIONs")
plt.show()

# %%
sns.barplot(x="SECTION", y="FL", data=df)
plt.title('Barplot of Mean DV Across Sections')
plt.show()

# %%
sns.scatterplot(x="DV", y="TOTAL", data=df)
plt.title('Scatter Plot of DV vs TOTAL')
plt.show()

# %%
sns.histplot(df['DV'], bins=30)
plt.title('Distribution of DV')
plt.show()

# %%
section_counts = df['SECTION'].value_counts()
section_counts.plot.pie(autopct='%1.1f%%', figsize=(7, 7))
plt.title('Proportion of Each SECTION')
plt.ylabel('')
plt.show()

# %%
dff = df[['M2', 'PP', 'BEEE', 'FL', 'FIMS']].melt(var_name='Subject', value_name='Marks')
sns.boxplot(x="Subject", y="Marks", data=dff)
plt.title('Boxplot of Marks for Each Subject')
plt.show()

# %%
df_backlog = pd.DataFrame(backlog_counts)
print(df_backlog.reset_index())
# Out:
#    SECTION  DV  M2  PP  BEEE  FL  FIMS
# 0    ALPHA  17  18  12     8   1    22
# 1     BETA  17  25   8    41   1    11
# 2    DELTA  14  45  28    46   1     4
# 3  EPSILON   4  64  49    17   8    22
# 4    GAMMA  11  46  36    17   2    23
# 5    OMEGA  10  58  16    21  12     7
# 6    SIGMA   6  28  14    23   2     9
# 7     ZETA   8  63  50    18  15    20

# %%
backlog_counts.reset_index(inplace=True)
backlog_counts['TOTAL_BACKLOGS'] = backlog_counts[subject_cols].sum(axis=1)

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=backlog_counts, x="SECTION", y="TOTAL_BACKLOGS")
plt.title("Total Backlogs by Section")
plt.xlabel("Section")
plt.ylabel("Total Backlogs")
# Out:
# Text(0, 0.5, 'Total Backlogs')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.barplot(data=backlog_counts, x="SECTION", y="TOTAL_BACKLOGS",color="teal")  # Teal color
plt.title("Total Backlogs by Section")
plt.xlabel("Section")
plt.ylabel("Total Backlogs")

plt.show()

# %%
subject = 'DV'
subject_counts = df_backlog[subject].sum()
plt.figure(figsize=(6,6))
plt.pie(df_backlog[subject], labels=df_backlog.index, autopct='%1.1f%%', startangle=90)
plt.title(f'Pie Plot of {subject} Backlogs by Section')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.histplot(df_backlog['M2'], kde=True, bins=8)
plt.title('Histogram of M2 Backlogs')
plt.xlabel('Number of Backlogs')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.lineplot(x=df_backlog.index, y=df_backlog['FL'])
plt.title('Line Plot of FL Backlogs by Section')
plt.xlabel('Sections')
plt.ylabel('Number of Backlogs')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x=df_backlog['M2'], y=df_backlog['PP'])
plt.title('Scatter Plot of M2 vs PP Backlogs')
plt.xlabel('M2 Backlogs')
plt.ylabel('PP Backlogs')
plt.show()

# %%
total_backlogs = df_backlog.sum()
total_backlogs_df = total_backlogs.reset_index()
total_backlogs_df.columns = ['Subject', 'Total Backlogs']

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=total_backlogs_df, x="Subject", y="Total Backlogs")
plt.title("Total Backlogs by Subject")
plt.xlabel("Subject")
plt.ylabel("Total Backlogs")
plt.tight_layout()
plt.show()

# %%
# Plotting pie chart
plt.figure(figsize=(8, 8))
plt.pie(total_backlogs_df["Total Backlogs"], labels=total_backlogs_df["Subject"], autopct="%1.1f%%", startangle=140)
plt.title("Total Backlogs by Subject")
plt.show()

# %%
df['Grade']=pd.cut(df['TOTAL'],bins=[0,60,70,80,90,100],labels=['F','D','C','B','A']);
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_21436\1394100974.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Grade']=pd.cut(df['TOTAL'],bins=[0,60,70,80,90,100],labels=['F','D','C','B','A']);

# %%
def assign_grade(PP):
    if PP >=18 :
        return "very good"
    elif PP >=15 :
        return 'good'
    elif PP >= 13:
        return 'average'
    else:
        return 'poor'
df['Coding_skills in DV'] = df['PP'].apply(assign_grade)
df
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_21436\150282539.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Coding_skills in DV'] = df['PP'].apply(assign_grade)
#      S.NO SECTION    DV    M2    PP  BEEE    FL  FIMS  BC  IS_BACKLOG  \
# 0       1   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0   2       False
# 1       2   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0   1       False
# 2       3   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0   0       False
# 3       4   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0   1       False
# 4       5   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0   0       False
# ..    ...     ...   ...   ...   ...   ...   ...   ...  ..         ...
# ...

# %%
columns_to_drop = ['Coding-skills in DV']
df = df.drop(columns=columns_to_drop, errors='ignore')

# %%
df
# Out:
#      S.NO SECTION    DV    M2    PP  BEEE    FL  FIMS  BC  IS_BACKLOG  \
# 0       1   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0   2       False
# 1       2   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0   1       False
# 2       3   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0   0       False
# 3       4   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0   1       False
# 4       5   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0   0       False
# ..    ...     ...   ...   ...   ...   ...   ...   ...  ..         ...
# 713   714    ZETA  19.0   8.0   8.0  19.0  17.0  18.0   2       False
# 714   715    ZETA  12.0   1.0   7.0  10.0  20.0   8.0   3       False
# 715   716    ZETA  17.0   6.0  14.0  14.0  17.0  18.0   1       False
# 716   717    ZETA  12.0   1.0   6.0   7.0  15.0  12.0   3       False
# 717   718    ZETA  19.0  14.0  17.0  16.0  20.0  19.0   0       False
#
#      TOTAL_BACKLOGS  Total Backlogs  Total Grade  Percentage  TOTAL  \
# ...

# %%
subjects = ['DV', 'M2', 'PP', 'BEEE', 'FL', 'FIMS']
subset = df[df[subjects].eq(20).any(axis=1)]
print("Subset of students who scored 20 in any subject:")
print(subset)
for subject in subjects:
    count_20 = (df[subject] == 20).sum()
    print(f"Students who scored 20 in {subject}: {count_20}")
# Out:
# Subset of students who scored 20 in any subject:
#      S.NO SECTION    DV    M2    PP  BEEE    FL  FIMS  BC  IS_BACKLOG  \
# 4       5   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0   0       False
# 6       7   ALPHA  15.0  10.0  20.0  20.0  15.0  14.0   0       False
# 7       8   ALPHA  17.0  17.0  19.0  20.0  19.0  13.0   0       False
# 8       9   ALPHA  10.0  18.0   0.0  20.0  19.0  15.0   1       False
# 9      10   ALPHA  18.0  19.0  20.0  20.0  20.0  15.0   0       False
# ..    ...     ...   ...   ...   ...   ...   ...   ...  ..         ...
# 705   706    ZETA  16.0   0.0  11.0  16.0  20.0   0.0   2       False
# 709   710    ZETA  19.0  17.0  12.0  17.0  20.0  16.0   0       False
# 711   712    ZETA  18.0   9.0  12.0  20.0  16.0  16.0   1       False
# 714   715    ZETA  12.0   1.0   7.0  10.0  20.0   8.0   3       False
# 717   718    ZETA  19.0  14.0  17.0  16.0  20.0  19.0   0       False
#
#      TOTAL_BACKLOGS  Total Backlogs  Total Grade  Percentage  TOTAL  \
# ...

# %%
subject = 'Coding_skills in DV'
if subject in df_backlog.columns:
    subject_counts = df_backlog[subject].sum()
    plt.figure(figsize=(6, 6))
    plt.pie(df_backlog[subject], labels=df_backlog.index, autopct='%1.1f%%', startangle=90)
    plt.title(f'Pie Plot of {subject} Backlogs by Section')
    plt.show()
else:
    print(f"Column '{subject}' not found in the DataFrame.")
# Out:
# Column 'Coding_skills in DV' not found in the DataFrame.

# %%
print(df_backlog.columns)
# Out:
# Index(['DV', 'M2', 'PP', 'BEEE', 'FL', 'FIMS'], dtype='object')

# %%
import pandas as pd
passing_threshold = 10
pass_count = df[df['DV'] >= passing_threshold].shape[0]
total_count = df.shape[0]
pass_probability = pass_count / total_count
print("Pass Probability:", pass_probability)
# Out:
# Pass Probability: 0.8784916201117319

# %%
D=(df['DV']<10)&(df['SECTION']=='ALPHA')
D.value_counts()
# Out:
# False    699
# True      17
# Name: count, dtype: int64

# %%
D=(df['DV']<10)&(df['SECTION']=='SIGMA')
D.value_counts()
# Out:
# False    710
# True       6
# Name: count, dtype: int64

# %%
import pandas as pd
passing_threshold = 8
pass_count = df[df['M2'] >= passing_threshold].shape[0]
total_count = df.shape[0]
pass_probability = pass_count / total_count
print("Pass Probability:", pass_probability)
# Out:
# Pass Probability: 0.6075418994413407

# %%
import pandas as pd
k = pd.read_csv("midmarks.csv")
for col in k.columns[2:]:
    k[col] = pd.to_numeric(k[col], errors='coerce')
passing_marks = 10
subject_section_pass = k.groupby('SECTION').apply(
    lambda df: (df.iloc[:, 2:] >= passing_marks).sum()
)
subject_section_fail = k.groupby('SECTION').apply(
    lambda df: (df.iloc[:, 2:] < passing_marks).sum()
)
total_students_per_section = k.groupby('SECTION').size()
prob_pass = subject_section_pass.div(total_students_per_section, axis=0)
prob_fail = subject_section_fail.div(total_students_per_section, axis=0)
print("Number of students passing each subject in each section:")
print(subject_section_pass)
print("\nNumber of students failing each subject in each section:")
print(subject_section_fail)
print("\nProbability of students passing each subject in each section:")
print(prob_pass)
print("\nProbability of students failing each subject in each section:")
print(prob_fail)
# Out:
# Number of students passing each subject in each section:
#          DV  M-II  PP  BEEE  FL  FIMS
# SECTION
# ALPHA    73    72  78    82  89    68
# BETA     73    65  82    49  89    79
# DELTA    76    45  62    44  89    86
# EPSILON  84    24  39    71  80    66
# GAMMA    79    44  54    73  88    67
# OMEGA    80    32  74    69  78    83
# SIGMA    57    43  51    46  60    55
# ZETA     82    27  40    72  75    70
#
# Number of students failing each subject in each section:
#          DV  M-II  PP  BEEE  FL  FIMS
# SECTION
# ALPHA    17    18  11     7   0    21
# BETA     17    25   7    40   0    11
# DELTA    12    43  27    44   0     2
# EPSILON   3    63  48    16   7    21
# GAMMA     8    43  33    14   0    19
# OMEGA     8    56  13    15   7     0
# SIGMA     3    17   8    14   0     3
# ZETA      7    61  48    16  14    17
#
# Probability of students passing each subject in each section:
#                DV      M-II        PP      BEEE        FL      FIMS
# ...

# %%
df[df['SECTION']=="ALPHA"].mean(numeric_only =True)
# Out:
# S.NO              45.500000
# DV                13.411111
# M2                13.711111
# PP                15.933333
# BEEE              15.622222
# FL                16.177778
# FIMS              12.700000
# BC                 0.866667
# IS_BACKLOG         0.188889
# TOTAL_BACKLOGS     0.866667
# Total Backlogs     0.866667
# Total             87.555556
# Percentage        14.592593
# TOTAL             87.555556
# dtype: float64

# %%
df[df['SECTION']=="ALPHA"].std(numeric_only =True)
# Out:
# S.NO              26.124701
# DV                 4.991891
# M2                 5.595432
# PP                 5.343903
# BEEE               4.803037
# FL                 3.808854
# FIMS               4.498314
# BC                 1.317130
# IS_BACKLOG         0.393613
# TOTAL_BACKLOGS     1.317130
# Total Backlogs     1.317130
# Total             23.435357
# Percentage         3.905893
# TOTAL             23.435357
# dtype: float64

# %%
t_stat = (13.411111 - 716 )/(4.991891/(716 ** 0.5))

# %%
t_stat
# Out:
# -3766.107347436025

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 716 entries, 0 to 717
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   S.NO                 716 non-null    int64
#  1   SECTION              716 non-null    object
#  2   DV                   716 non-null    float64
#  3   M2                   716 non-null    float64
#  4   PP                   716 non-null    float64
#  5   BEEE                 716 non-null    float64
#  6   FL                   716 non-null    float64
#  7   FIMS                 716 non-null    float64
#  8   BC                   716 non-null    int64
#  9   IS_BACKLOG           716 non-null    bool
#  10  TOTAL_BACKLOGS       716 non-null    int64
#  11  Total Backlogs       716 non-null    int64
#  12  Total                716 non-null    float64
#  13  Grade                526 non-null    category
#  14  Percentage           716 non-null    float64
# ...

# %%
df[df['SECTION']=="ALPHA"].mean(numeric_only =True)
# Out:
# S.NO              45.500000
# DV                13.411111
# M2                13.711111
# PP                15.933333
# BEEE              15.622222
# FL                16.177778
# FIMS              12.700000
# BC                 0.866667
# IS_BACKLOG         0.188889
# TOTAL_BACKLOGS     0.866667
# Total Backlogs     0.866667
# Total             87.555556
# Percentage        14.592593
# TOTAL             87.555556
# dtype: float64

# %%
subject_cols = ['DV', 'M2', 'PP', 'BEEE', 'FL', 'FIMS']
Mean = df[subject_cols].lt(10).groupby(df['SECTION']).sum().mean(numeric_only = True)
mean=Mean.mean(numeric_only = True)
print(mean)
# Out:
# 20.791666666666668

# %%
subject_cols = ['DV', 'M2', 'PP', 'BEEE', 'FL', 'FIMS']
mean = df[subject_cols].lt(10).groupby(df['SECTION']).sum().mean(numeric_only = True)
print(mean)
# Out:
# DV      10.875
# M2      43.375
# PP      26.625
# BEEE    23.875
# FL       5.250
# FIMS    14.750
# dtype: float64

# %%
subject_cols = ['DV', 'M2', 'PP', 'BEEE', 'FL', 'FIMS']
mean = df[subject_cols].lt(10).groupby(df['SECTION']).mean(numeric_only = True)
print(mean)
# Out:
#                DV        M2        PP      BEEE        FL      FIMS
# SECTION
# ALPHA    0.188889  0.200000  0.133333  0.088889  0.011111  0.244444
# BETA     0.188889  0.277778  0.088889  0.455556  0.011111  0.122222
# DELTA    0.155556  0.500000  0.311111  0.511111  0.011111  0.044444
# EPSILON  0.045455  0.727273  0.556818  0.193182  0.090909  0.250000
# GAMMA    0.122222  0.511111  0.400000  0.188889  0.022222  0.255556
# OMEGA    0.111111  0.644444  0.177778  0.233333  0.133333  0.077778
# SIGMA    0.068182  0.318182  0.159091  0.261364  0.022727  0.102273
# ZETA     0.088889  0.700000  0.555556  0.200000  0.166667  0.222222

# %%
from scipy.stats import ttest_ind

# %%
df[df["SECTION"]=="ALPHA"]["DV"]
# Out:
# 0     12.0
# 1     19.0
# 2     18.0
# 3     15.0
# 4     18.0
#       ...
# 85     3.0
# 86    17.0
# 87    13.0
# 88     2.0
# 89    10.0
# Name: DV, Length: 90, dtype: float64

# %%
ttest_ind(df[df['SECTION']=='ALPHA']['DV'],df[df['SECTION']=='GAMMA']['DV'])
# Out:
# TtestResult(statistic=-1.8800770928260777, pvalue=0.061731245762473755, df=178.0)

# %%
ttest_ind(df[df['SECTION']=='ALPHA']['DV'],df[df['SECTION']=='GAMMA']['DV'],equal_var=False)
# Out:
# TtestResult(statistic=-1.880077092826078, pvalue=0.06173124874722092, df=177.99967517670504)

# %%
from scipy.stats import ttest_rel

# %%
ttest_rel(df[df['SECTION']=='ALPHA']['DV'],df[df['SECTION']=='GAMMA']['DV'])
# Out:
# TtestResult(statistic=-1.769224101059647, pvalue=0.08028203231580917, df=89)

# %%
df[df["SECTION"]=="ALPHA"]["DV"].mean()
# Out:
# 13.411111111111111

# %%
import scipy.stats as stats

# %%
t_statistic,p_value=stats.ttest_1samp(df[df['SECTION']=='ALPHA']['DV'],df.DV.mean())
print(t_statistic,p_value)
# Out:
# -2.616154646179782 0.010446384280899498
