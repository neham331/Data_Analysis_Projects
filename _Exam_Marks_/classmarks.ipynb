# %% [markdown]
# # 2211CS010331

# %%
import pandas as pd

# %%
dt = pd.read_csv("class_marks.csv")

# %%
dt
# Out:
#     Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  Q5M10  \
# 0      37    4.0    5.0    6.0    4.0    2.0    1.0    NaN    5.0    8.0
# 1      32    4.0    3.0    4.0    3.0    NaN    NaN    3.0    6.0    9.0
# 2      33    4.0    5.0    5.0    1.0    5.0    5.0    NaN    NaN    8.0
# 3      24    4.0    6.0    6.0    3.0    2.0    2.0    NaN    NaN    NaN
# 4      36    3.0    6.0    4.0    4.0    5.0    4.0    NaN    NaN   10.0
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 81     32    3.0    6.0    3.0    4.0    5.0    3.0    NaN    NaN    NaN
# 82     27    2.0    2.0    5.0    3.0    NaN    NaN    NaN    NaN    7.0
# 83     37    4.0    6.0    6.0    2.0    NaN    NaN    NaN    NaN    9.0
# 84     28    4.0    NaN    5.0    4.0    5.0    4.0    NaN    NaN    6.0
# 85     29    4.0    6.0    NaN    NaN    NaN    NaN    3.0    5.0    7.0
#
#     Q6aM4  Q6bM6
# 0     4.0    6.0
# 1     NaN    NaN
# 2     NaN    NaN
# 3     2.0    NaN
# ...

# %%
dt.shape
# Out:
# (86, 12)

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86 entries, 0 to 85
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Total   86 non-null     int64
#  1   Q1aM4   85 non-null     float64
#  2   Q1bM6   73 non-null     float64
#  3   Q2aM6   72 non-null     float64
#  4   Q2bM4   75 non-null     float64
#  5   Q3aM5   52 non-null     float64
#  6   Q3bM5   51 non-null     float64
#  7   Q4aM3   32 non-null     float64
#  8   Q4bM7   26 non-null     float64
#  9   Q5M10   56 non-null     float64
#  10  Q6aM4   33 non-null     float64
#  11  Q6bM6   28 non-null     float64
# dtypes: float64(11), int64(1)
# memory usage: 8.2 KB

# %%
dt.head()
# Out:
#    Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  Q5M10  \
# 0     37    4.0    5.0    6.0    4.0    2.0    1.0    NaN    5.0    8.0
# 1     32    4.0    3.0    4.0    3.0    NaN    NaN    3.0    6.0    9.0
# 2     33    4.0    5.0    5.0    1.0    5.0    5.0    NaN    NaN    8.0
# 3     24    4.0    6.0    6.0    3.0    2.0    2.0    NaN    NaN    NaN
# 4     36    3.0    6.0    4.0    4.0    5.0    4.0    NaN    NaN   10.0
#
#    Q6aM4  Q6bM6
# 0    4.0    6.0
# 1    NaN    NaN
# 2    NaN    NaN
# 3    2.0    NaN
# 4    NaN    NaN

# %%
dt.describe()
# Out:
#            Total      Q1aM4      Q1bM6      Q2aM6     Q2bM4      Q3aM5  \
# count  86.000000  85.000000  73.000000  72.000000  75.00000  52.000000
# mean   29.360465   3.141176   4.972603   5.291667   3.20000   4.173077
# std     7.839437   1.013633   1.246914   1.155970   1.03975   1.294349
# min     3.000000   0.000000   2.000000   1.000000   1.00000   1.000000
# 25%    25.000000   2.000000   4.000000   5.000000   2.00000   3.750000
# 50%    31.000000   4.000000   5.000000   6.000000   4.00000   5.000000
# 75%    36.000000   4.000000   6.000000   6.000000   4.00000   5.000000
# max    40.000000   4.000000   6.000000   6.000000   4.00000   5.000000
#
#            Q3bM5      Q4aM3      Q4bM7      Q5M10      Q6aM4      Q6bM6
# count  51.000000  32.000000  26.000000  56.000000  33.000000  28.000000
# mean    4.098039   2.468750   4.884615   8.000000   3.484848   4.964286
# std     1.345435   0.761339   2.196851   1.705606   0.972150   1.502643
# ...

# %%
dt.isnull()
# Out:
#     Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  Q5M10  \
# 0   False  False  False  False  False  False  False   True  False  False
# 1   False  False  False  False  False   True   True  False  False  False
# 2   False  False  False  False  False  False  False   True   True  False
# 3   False  False  False  False  False  False  False   True   True   True
# 4   False  False  False  False  False  False  False   True   True  False
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 81  False  False  False  False  False  False  False   True   True   True
# 82  False  False  False  False  False   True   True   True   True  False
# 83  False  False  False  False  False   True   True   True   True  False
# 84  False  False   True  False  False  False  False   True   True  False
# 85  False  False  False   True   True   True   True  False  False  False
#
#     Q6aM4  Q6bM6
# 0   False  False
# 1    True   True
# 2    True   True
# 3   False   True
# ...

# %%
dt.isnull().sum()
# Out:
# Total     0
# Q1aM4     1
# Q1bM6    13
# Q2aM6    14
# Q2bM4    11
# Q3aM5    34
# Q3bM5    35
# Q4aM3    54
# Q4bM7    60
# Q5M10    30
# Q6aM4    53
# Q6bM6    58
# dtype: int64

# %%
dt.fillna(0)
# Out:
#     Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  Q5M10  \
# 0      37    4.0    5.0    6.0    4.0    2.0    1.0    0.0    5.0    8.0
# 1      32    4.0    3.0    4.0    3.0    0.0    0.0    3.0    6.0    9.0
# 2      33    4.0    5.0    5.0    1.0    5.0    5.0    0.0    0.0    8.0
# 3      24    4.0    6.0    6.0    3.0    2.0    2.0    0.0    0.0    0.0
# 4      36    3.0    6.0    4.0    4.0    5.0    4.0    0.0    0.0   10.0
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 81     32    3.0    6.0    3.0    4.0    5.0    3.0    0.0    0.0    0.0
# 82     27    2.0    2.0    5.0    3.0    0.0    0.0    0.0    0.0    7.0
# 83     37    4.0    6.0    6.0    2.0    0.0    0.0    0.0    0.0    9.0
# 84     28    4.0    0.0    5.0    4.0    5.0    4.0    0.0    0.0    6.0
# 85     29    4.0    6.0    0.0    0.0    0.0    0.0    3.0    5.0    7.0
#
#     Q6aM4  Q6bM6
# 0     4.0    6.0
# 1     0.0    0.0
# 2     0.0    0.0
# 3     2.0    0.0
# ...

# %%
dt ["Total"]
# Out:
# 0     37
# 1     32
# 2     33
# 3     24
# 4     36
#       ..
# 81    32
# 82    27
# 83    37
# 84    28
# 85    29
# Name: Total, Length: 86, dtype: int64

# %%
dt.Total.sum()
# Out:
# 2525

# %%
dt.Total.count
# Out:
# <bound method Series.count of 0     37
# 1     32
# 2     33
# 3     24
# 4     36
#       ..
# 81    32
# 82    27
# 83    37
# 84    28
# 85    29
# Name: Total, Length: 86, dtype: int64>

# %%
dt.Total.mean()
# Out:
# 29.36046511627907

# %%
dt[(dt['Q1aM4'] > 50) & (dt['Q1bM6'] == 'Yes')]
# Out:
# Empty DataFrame
# Columns: [Total, Q1aM4, Q1bM6, Q2aM6, Q2bM4, Q3aM5, Q3bM5, Q4aM3, Q4bM7, Q5M10, Q6aM4, Q6bM6]
# Index: []

# %%
dt.isna()
# Out:
#     Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  Q5M10  \
# 0   False  False  False  False  False  False  False   True  False  False
# 1   False  False  False  False  False   True   True  False  False  False
# 2   False  False  False  False  False  False  False   True   True  False
# 3   False  False  False  False  False  False  False   True   True   True
# 4   False  False  False  False  False  False  False   True   True  False
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 81  False  False  False  False  False  False  False   True   True   True
# 82  False  False  False  False  False   True   True   True   True  False
# 83  False  False  False  False  False   True   True   True   True  False
# 84  False  False   True  False  False  False  False   True   True  False
# 85  False  False  False   True   True   True   True  False  False  False
#
#     Q6aM4  Q6bM6
# 0   False  False
# 1    True   True
# 2    True   True
# 3   False   True
# ...

# %%
dt.rename(columns={'Total': 'TOTAL'}, inplace=True)

# %%
dt
# Out:
#     TOTAL  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  Q5M10  \
# 0      37    4.0    5.0    6.0    4.0    2.0    1.0    NaN    5.0    8.0
# 1      32    4.0    3.0    4.0    3.0    NaN    NaN    3.0    6.0    9.0
# 2      33    4.0    5.0    5.0    1.0    5.0    5.0    NaN    NaN    8.0
# 3      24    4.0    6.0    6.0    3.0    2.0    2.0    NaN    NaN    NaN
# 4      36    3.0    6.0    4.0    4.0    5.0    4.0    NaN    NaN   10.0
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 81     32    3.0    6.0    3.0    4.0    5.0    3.0    NaN    NaN    NaN
# 82     27    2.0    2.0    5.0    3.0    NaN    NaN    NaN    NaN    7.0
# 83     37    4.0    6.0    6.0    2.0    NaN    NaN    NaN    NaN    9.0
# 84     28    4.0    NaN    5.0    4.0    5.0    4.0    NaN    NaN    6.0
# 85     29    4.0    6.0    NaN    NaN    NaN    NaN    3.0    5.0    7.0
#
#     Q6aM4  Q6bM6
# 0     4.0    6.0
# 1     NaN    NaN
# 2     NaN    NaN
# 3     2.0    NaN
# ...

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt
dt=pd.read_csv("class_marks.csv")

# %%
dt.plot()
plt.show()

# %%
dt.columns
# Out:
# Index(['Total', 'Q1aM4', 'Q1bM6', 'Q2aM6', 'Q2bM4', 'Q3aM5', 'Q3bM5', 'Q4aM3',
#        'Q4bM7', 'Q5M10', 'Q6aM4', 'Q6bM6'],
#       dtype='object')

# %%
dt['Q1'] = dt['Q1aM4'] + dt['Q1bM6']
plt.hist(dt['Q1'], color='red', edgecolor='black', bins=9)
plt.xlabel("Marks scored in Q1")
plt.ylabel("No. of students")
plt.title("Histogram of Q1")
plt.show()

# %% [markdown]
# # The distribution is moderately spread with more students scoring in the middle range.

# %%
dt['Q2'] = dt['Q2aM6'] + dt['Q2bM4']
plt.hist(dt["Q2"], color='yellow', edgecolor='black', bins=10)
plt.xlabel("Marks scored in Q2")
plt.ylabel("No. of students")
plt.title("Histogram of Q2")
plt.show()

# %% [markdown]
# # The distribution is relatively even with a slight right skew, indicating more students scored lower.

# %%
dt['Q4'] = dt['Q4aM3'] + dt["Q4bM7"]
plt.hist(dt["Q4"], color='green', edgecolor='black', bins=10)
plt.xlabel("Marks scored in Q4")
plt.ylabel("No. of students")
plt.title("Histogram of Q4")
plt.show()

# %% [markdown]
# #  The data shows a left-skewed distribution with most students scoring in the lower range.

# %%
plt.hist(dt["Q5M10"], color='purple', edgecolor='black', bins=10)
plt.xlabel("Marks scored in Q5")
plt.ylabel("No. of students")
plt.title("Histogram of Q5")
plt.show()

# %% [markdown]
# # The scores are concentrated in the higher range, with a few students achieving significantly higher marks.

# %%
plt.hist(dt['Total'], color='brown', edgecolor='black', bins=10)
plt.xlabel("Marks scored in Q8")
plt.ylabel("No. of students")
plt.title("Histogram of Q8")
plt.show()

# %% [markdown]
# # The distribution is evenly spread with a few students scoring exceptionally high.

# %%
dt.plot.scatter(x='Q1bM6', y='Total', color='magenta', s=30)
plt.title("Scatter Plot for Q1bM6 vs Total")
plt.show()

# %% [markdown]
# # There is a mild positive correlation between Q1bM6 scores and total marks, indicating some dependency.

# %%
dt.plot.scatter(x='Q2bM4', y='Total', color='green', s=30)
plt.title("Scatter Plot for Q2bM4 vs Total")
plt.show()

# %% [markdown]
# # There is a noticeable positive correlation between Q2bM4 scores and total marks.

# %%
dt.plot.scatter(x='Q3aM5', y='Total', color='blue', s=30)
plt.title("Scatter Plot for Q3aM5 vs Total")
plt.show()

# %% [markdown]
# # A weak positive correlation can be observed between Q3aM5 scores and total marks.

# %%
dt.plot.scatter(x='Q5M10', y='Total', color='brown', s=30)
plt.title("Scatter Plot for Q5M10 vs Total")
plt.show()

# %% [markdown]
# # Strong positive correlation between Q5M10 scores and total marks, indicating a significant impact on the total score.

# %%
dt['Q3'] = dt['Q3aM5'] + dt['Q3bM5']
dt.plot.scatter(x='Q3', y='Total', color='green', s=30)
plt.title("Scatter Plot for Q3")
plt.show()

# %% [markdown]
# # The correlation between Q3 scores and total marks appears weak but slightly positive.

# %%
dt.plot.scatter(x='Q5M10', y='Total', color='blue', s=25)
plt.title("Scatter Plot for Q5")
plt.show()

# %% [markdown]
# # A strong positive correlation between Q5 scores and total marks is evident, suggesting Q5 plays a significant role in the total marks.

# %%
dt.boxplot(by='Q1aM4', column =['Total'], grid = False, color='purple')
plt.title("Boxplot of Q1aM4")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# # This boxplot shows the distribution of total marks across different values of Q1aM4. The spread of data is relatively wide.

# %%
dt.boxplot(by='Q1bM6', column =['Total'], grid = False, color='blue')
plt.title("Boxplot of Q1bM6")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# # The distribution of total marks based on Q1bM6 indicates a moderate spread with some outliers.

# %%
dt.boxplot(by='Q3bM5', column =['Total'], grid = False, color='green')
plt.title("Boxplot of Q3bM5")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# # A tight distribution for Q3bM5 values with a few outliers present in the total marks data.

# %%
dt.boxplot(by='Q5M10', column =['Total'], grid = False, color='red')
plt.title("Boxplot of Q5M10")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# # The distribution for total marks based on Q5M10 is wide, with multiple outliers showing varied performance.

# %%
dt.boxplot(by='Q5M10', column=['Total'], grid=False, color='teal')
plt.title("Boxplot of Q5")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# # Q5 has a relatively consistent distribution, with some higher marks showing noticeable differences.

# %%
dt.plot.line(x='Q2', y='Total', color='blue')
plt.title("Line Graph of Q2")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# # Q2's line graph displays a steady upward trend, showing gradual improvement in total marks for the students.

# %%
dt.plot.line(x='Q3', y='Total', color='red')
plt.title("Line Graph of Q3")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# # The line for Q3 fluctuates moderately, suggesting mixed student performances with some peaks.

# %%
dt.plot.line(x='Q5M10', y='Total', color='purple')
plt.title("Line Graph of Q5")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# # The line graph for Q5 shows a steady slope, with a few sharp increases indicating exceptional student performance in certain cases.

# %%
dt.plot.line(x='Q2bM4', y='Total', color='orange')
plt.title("Line Graph of Q2bM4")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# # The graph for Q2bM4 has a rising slope, suggesting consistent performance improvement.

# %%
n=pd.read_csv("class_marks.csv",skiprows=70)
n
n['3'].plot(kind='pie',figsize=(4,10))
plt.title("Piechart of marks in Q2")
# Out:
# Text(0.5, 1.0, 'Piechart of marks in Q2')

# %% [markdown]
# # The pie chart for Q2 represents the proportion of different marks achieved in that section, with varied colors for each category.

# %%
n=pd.read_csv("class_marks.csv",skiprows=70)
n
n['1'].plot(kind='pie',figsize=(5,10))
plt.title("Piechart of marks in Q3")
# Out:
# Text(0.5, 1.0, 'Piechart of marks in Q3')

# %% [markdown]
# # The pie chart for Q3 illustrates the distribution of marks in Q3, with contrasting colors showing the percentage of each mark category.

# %%
n=pd.read_csv("class_marks.csv",skiprows=70)
n
n['1.1'].plot(kind='pie',figsize=(4,10))
plt.title("Piechart of marks in Q5")
# Out:
# Text(0.5, 1.0, 'Piechart of marks in Q5')

# %% [markdown]
# # The pie chart for Q5 shows the mark distribution, with bright colors representing the varying marks achieved in that section.
